# %% [markdown]
# # Introduction
# This notebook creates data files to explore the influences of economic growth in Western Australia

# %% [markdown]
# # Western Australia
# ## Economic indicators
# ### Source files
# __[Australian Bureau of Statistics,5220.0 Australian National Accounts: State Accounts; Table 6. Expenditure, Income and Industry Components of Gross State Product, Western Australia, Chain volume measures and current prices
# ](https://www.abs.gov.au/AUSSTATS/abs@.nsf/DetailsPage/5220.02018-19?OpenDocument)__

# %%
# import csv files
filePath1_WA <- paste0(getwd(),'/ABS_5220006_WA.csv')
df_GRA_WA <- read.csv(filePath1, stringsAsFactors = FALSE)
head(df_GRA_WA)
# Out:
#   Date   A2335882X A2335883A A2335884C A2335885F A2335886J A2335887K A2335888L
# 1 Jun-90 3517      10866     14219     4601      3794      1036       9038
# 2 Jun-91 3608      10956     14418     4719      3613       954       9414
# 3 Jun-92 3793      11050     14741     4990      3621       994       9761
# 4 Jun-93 3911      11371     15179     5140      3826      1072      10087
# 5 Jun-94 4083      11513     15528     5278      3462      1106      10528
# 6 Jun-95 4236      11573     15778     5524      3494      1175      10990
#   A2335889R A2335890X ... A2714831X A2714832A A2714833C A2714834F A2714835J
# 1  979      1699      ... NA        NA        NA        NA        NA
# 2 1039      1651      ...  0         0         0         0         0
# 3 1060      1757      ...  0         0         0         0         0
# 4 1134      1956      ...  0         0         0         0         0
# 5 1149      2120      ...  0         0         0         0         0
# ...

# %%
# import meta data file- Source: 5220.0 Australian National Accounts: State Accounts; Table 6. Expenditure, Income and Industry Components of Gross State Product, Western Australia, Chain volume measures and current prices
filepath2_WA <- paste0(getwd(),'/ABS_5220006_WA_META.csv')
df_GRP_WA_meta <- read.csv(filepath2_WA, stringsAsFactors = FALSE)
df_GRP_WA_meta
# Out:
#     SeriesID
# 1   A2335882X
# 2   A2335883A
# 3   A2335884C
# 4   A2335885F
# 5   A2335886J
# 6   A2335887K
# 7   A2335888L
# 8   A2335889R
# 9   A2335890X
# 10  A2335891A
# 11  A2335892C
# 12  A2335893F
# 13  A2335894J
# 14  A2335895K
# 15  A2335896L
# 16  A2335897R
# 17  A2335898T
# 18  A2335899V
# 19  A2335900T
# 20  A2335911X
# 21  A2335912A
# 22  A2335904A
# 23  A2335905C
# 24  A2335906F
# 25  A2335907J
# 26  A2335901V
# 27  A2335902W
# 28  A2335903X
# 29  A2713891J
# 30  A2713925V
# ... ...
# 335 A2715869X
# 336 A2715870J
# 337 A2715943K
# 338 A2715952L
# 339 A2529290A
# 340 A2478628R
# 341 A2478630A
# 342 A2714818F
# 343 A2714819J
# 344 A2714820T
# 345 A2714821V
# 346 A2714822W
# 347 A2714823X
# 348 A2714824A
# 349 A2714825C
# 350 A2714826F
# 351 A2714827J
# 352 A2714828K
# 353 A2714829L
# 354 A2714830W
# 355 A2714831X
# 356 A2714832A
# 357 A2714833C
# 358 A2714834F
# 359 A2714835J
# 360 A2714836K
# 361 A2529272W
# 362 A2528438T
# 363 A2528439V
# 364 A2528440C
# ...

# %%
# WA_Selected_Variables_VAR.csv (Gross Value Added in levels)
filepath3_WA <- paste0(getwd(),'/','WA_Selected_Variables_VAR.csv')
df_GVA_Levels_WA <- read.csv(filepath3_WA, stringsAsFactors = FALSE)
df_GVA_Levels_WA
# Out:
#    Description
# 1  Financial and insurance services (K) ;  Industry gross value added
# 2  Arts and recreation services (R) ;  Industry gross value added
# 3  Retail trade (G) ;  Industry gross value added
# 4  Accommodation and food services (H) ;  Industry gross value added
# 5  Transport, postal and warehousing (I) ;  Industry gross value added
# 6  Public administration and safety (O) ;  Industry gross value added
# 7  Construction (E) ;  Industry gross value added
# 8  Wholesale trade (F) ;  Industry gross value added
# 9  Retail trade (G) ;  Industry gross value added
# 10 Professional, scientific and technical services (M) ;  Industry gross value added
# 11 Administrative and support services (N) ;  Industry gross value added
# 12 Manufacturing (C) ;  Industry gross value added
#    Levels    Percent.change
# 1  A2715104W A2714999C
# 2  A2715111V A2715006T
# 3  A2715100L A2714995V
# 4  A2715101R A2714996W
# 5  A2715102T A2714997X
# 6  A2715108F A2715003K
# ...

# %%
# Overseas variables
filepath4_OS <- paste0(getwd(),'/','OS_Data.csv')
df_OS <- read.csv(filepath4_OS, stringsAsFactors = FALSE)
df_OS
# Out:
#    Date      CHNLORSGPNOSTSAM CHNPRINTO01IXPYM GDPC1     INDPRO
# 1  1/06/1989 100.40693        #N/A              9238.923  63.5187
# 2  1/06/1990  96.06647        #N/A              9398.499  64.6041
# 3  1/06/1991  97.93574        #N/A              9388.845  63.4372
# 4  1/06/1992  98.70565        #N/A              9732.979  65.0295
# 5  1/06/1993 100.87403        #N/A              9955.641  66.8781
# 6  1/06/1994 101.73160        #N/A             10387.382  70.6763
# 7  1/06/1995 101.34371        #N/A             10665.060  73.8602
# 8  1/06/1996 101.22918        #N/A             11096.976  77.6669
# 9  1/06/1997 101.00935        #N/A             11615.636  82.2285
# 10 1/06/1998 100.12223        #N/A             12091.614  87.1450
# 11 1/06/1999  99.35663        109.1            12662.385  91.1994
# 12 1/06/2000  99.65411        112.2            13178.419  95.7353
# 13 1/06/2001  98.58526        110.1            13244.784  92.3208
# ...

# %%
# get meta data
filepath4_OS_meta <- paste0(getwd(),'/','OS_meta.csv')
df_OS_meta <- read.csv(filepath4_OS_meta, stringsAsFactors = FALSE)
df_OS_meta
# Out:
#   Variable
# 1 CHNLORSGPNOSTSAM
# 2 CHNPRINTO01IXPYM
# 3 GDPC1
# 4 INDPRO
# 5 PRENEL01CNQ656N
# 6 RGDPNACNA666NRUG
#   Description
# 1 Leading Indicators OECD: Reference series: Gross Domestic Product (GDP): Normalised for China
# 2 Production: Industry: Total industry: Total industry excluding construction for China
# 3 Real Gross Domestic Product (USA)
# 4 Industrial Production Index (USA)
# 5 Total Electricity Production for China
# 6 Real GDP at Constant National Prices for China
#   Source
# 1 https://fred.stlouisfed.org/series/CHNLORSGPNOSTSAM
# 2 https://fred.stlouisfed.org/series/CHNPRINTO01IXPYM
# 3 https://fred.stlouisfed.org/series/GDPC1
# 4 https://fred.stlouisfed.org/series/INDPRO
# 5 https://fred.stlouisfed.org/series/PRENEL01CNQ656N
# 6 https://fred.stlouisfed.org/series/RGDPNACNA666NRUG
