# %% [markdown]
# # Introduction
# This notebook contains an exploration of the inter-dependencies between industries across the States and Territories of Australia. The data is sourced from the Australian Bureau of Statistics: https://www.abs.gov.au/AUSSTATS/abs@.nsf/DetailsPage/5220.02018-19?OpenDocument

# %% [markdown]
# # Prepare the data

# %%
path <- getwd()
path
# Out:
# [1] "/home/nbuser/library"

# %%
data.WA <- read.csv(paste0(path,'/', 'ABS_5220006_WA.csv'), stringsAsFactor = FALSE)
meta.WA <- read.csv(paste0(path,'/', 'ABS_5220006_WA_META.csv'), stringsAsFactor = FALSE)

# %%
data.WA$Date <- seq(as.Date("1990/6/1"), as.Date("2019/6/1"), by = "year")

# %%
data.NSW <- read.csv(paste0(path,'/', 'ABS_5220002_NSW.csv'), stringsAsFactor = FALSE)
meta.NSW <- read.csv(paste0(path,'/', 'ABS_5220002_NSW_META.csv'), stringsAsFactor = FALSE)

# %%
data.NSW$Date <- seq(as.Date("1990/6/1"), as.Date("2019/6/1"), by = "year")

# %% [markdown]
# # Explore Western Australia

# %%
head(data.WA)
# Out:
#   Date       A2335882X A2335883A A2335884C A2335885F A2335886J A2335887K
# 1 1990-06-01 3517      10866     14219     4601      3794      1036
# 2 1991-06-01 3608      10956     14418     4719      3613       954
# 3 1992-06-01 3793      11050     14741     4990      3621       994
# 4 1993-06-01 3911      11371     15179     5140      3826      1072
# 5 1994-06-01 4083      11513     15528     5278      3462      1106
# 6 1995-06-01 4236      11573     15778     5524      3494      1175
#   A2335888L A2335889R A2335890X ... A2714831X A2714832A A2714833C A2714834F
# 1  9038      979      1699      ... NA        NA        NA        NA
# 2  9414     1039      1651      ...  0         0         0         0
# 3  9761     1060      1757      ...  0         0         0         0
# 4 10087     1134      1956      ...  0         0         0         0
# 5 10528     1149      2120      ...  0         0         0         0
# 6 10990     1233      2067      ...  0         0         0         0
# ...

# %%
# Show full descriptions of selected series
meta.WA[228:247,]
# Out:
#     SeriesID
# 228 A2714990J
# 229 A2714991K
# 230 A2714992L
# 231 A2714993R
# 232 A2714994T
# 233 A2714995V
# 234 A2714996W
# 235 A2714997X
# 236 A2714998A
# 237 A2714999C
# 238 A2715000C
# 239 A2715001F
# 240 A2715002J
# 241 A2715003K
# 242 A2715004L
# 243 A2715005R
# 244 A2715006T
# 245 A2715007V
# 246 A2529254T
# 247 A2478030W
#     Description
# 228 Mining (B) ;  Industry gross value added: Chain volume measures - Percentage changes ;
# 229 Manufacturing (C) ;  Industry gross value added: Chain volume measures - Percentage changes ;
# 230 Electricity, gas, water and waste services (D) ;  Industry gross value added: Chain volume measures - Percentage changes ;
# 231 Construction (E) ;  Industry gross value added: Chain volume measures - Percentage changes ;
# 232 Wholesale trade (F) ;  Industry gross value added: Chain volume measures - Percentage changes ;
# 233 Retail trade (G) ;  Industry gross value added: Chain volume measures - Percentage changes ;
# ...

# %%
head(data.WA[2:nrow(data.WA), 228:247])
# Out:
#   A2714989X A2714990J A2714991K A2714992L A2714993R A2714994T A2714995V
# 2  13.8     12.4      -5.1      3.2       -13.2     -7.5      -1.5
# 3 -14.4      7.7      -2.2      2.9        -1.1      2.8       8.6
# 4  17.6      1.7       3.6      3.7         9.6      8.8       7.6
# 5  14.4      9.7       0.7      7.6        19.0     13.2       7.0
# 6 -30.0     17.1       4.8      7.9        -7.1      8.3       3.4
# 7   8.8     12.8       1.3      1.4        24.2      7.3       7.7
#   A2714996W A2714997X A2714998A A2714999C A2715000C A2715001F A2715002J
# 2  7.0      -1.9       6.0      -0.5       2.3      -1.8       2.3
# 3  6.7       6.2       8.1       5.4       1.3       5.4       2.3
# 4  4.4      -0.4      13.2       8.6      10.6      -0.3       3.3
# 5 17.3      12.3       9.7      14.8       2.9      11.8       4.0
# 6 10.1       3.5      11.7      -2.2       9.5      20.6      17.3
# 7 -2.7       5.1       8.9       0.7       4.6      -0.5       7.9
# ...

# %%
M.WA<-cor(data.WA[2:nrow(data.WA), 228:247])
M.WA
# Out:
#           A2714989X    A2714990J    A2714991K   A2714992L    A2714993R
# A2714989X  1.000000000 -0.428772916  0.02635206 -0.064911091  0.1458148
# A2714990J -0.428772916  1.000000000 -0.39901253  0.001233079 -0.1345960
# A2714991K  0.026352058 -0.399012529  1.00000000 -0.096241994  0.4714443
# A2714992L -0.064911091  0.001233079 -0.09624199  1.000000000  0.3208119
# A2714993R  0.145814818 -0.134595967  0.47144426  0.320811856  1.0000000
# A2714994T  0.061766094 -0.175937360  0.28967657  0.149128626  0.5441931
# A2714995V  0.006962295 -0.172691979  0.36451958 -0.025779503  0.5132942
# A2714996W  0.104783678 -0.246431719  0.10568079  0.295432865  0.3004215
# A2714997X -0.044804440  0.048252628  0.16367802  0.061680340  0.4499597
# A2714998A -0.270105076  0.035470928  0.12476103  0.084099834  0.1748391
# A2714999C  0.179985594 -0.221081158  0.11512776 -0.177597891  0.2964823
# A2715000C  0.036576709  0.328847836 -0.07902184  0.346642859  0.4013207
# ...

# %%
# mat : is a matrix of data
# ... : further arguments to pass to the native R cor.test function
cor.mtest <- function(mat, ...) {
    mat <- as.matrix(mat)
    n <- ncol(mat)
    p.mat<- matrix(NA, n, n)
    diag(p.mat) <- 0
    for (i in 1:(n - 1)) {
        for (j in (i + 1):n) {
            tmp <- cor.test(mat[, i], mat[, j], ...)
            p.mat[i, j] <- p.mat[j, i] <- tmp$p.value
        }
    }
  colnames(p.mat) <- rownames(p.mat) <- colnames(mat)
  p.mat
}

# %%
# matrix of the p-value of the correlation
p.mat.WA <- cor.mtest(data.WA[2:nrow(data.WA), 228:247])
p.mat.WA
# Out:
#           A2714989X  A2714990J  A2714991K   A2714992L  A2714993R   A2714994T
# A2714989X 0.00000000 0.02029645 0.892065391 0.73797669 0.450402516 0.750262259
# A2714990J 0.02029645 0.00000000 0.032017603 0.99493488 0.486356024 0.361281763
# A2714991K 0.89206539 0.03201760 0.000000000 0.61944519 0.009832897 0.127450755
# A2714992L 0.73797669 0.99493488 0.619445186 0.00000000 0.089731624 0.440061545
# A2714993R 0.45040252 0.48635602 0.009832897 0.08973162 0.000000000 0.002275124
# A2714994T 0.75026226 0.36128176 0.127450755 0.44006155 0.002275124 0.000000000
# A2714995V 0.97140656 0.37034648 0.051879046 0.89439739 0.004404110 0.001160721
# A2714996W 0.58854254 0.19750817 0.585336304 0.11972332 0.113311126 0.025236536
# A2714997X 0.81748437 0.80369889 0.396212781 0.75059810 0.014320197 0.016460465
# A2714998A 0.15646064 0.85505564 0.519035741 0.66447738 0.364334437 0.253531868
# A2714999C 0.35016045 0.24910745 0.552048328 0.35669493 0.118352678 0.159550403
# ...

# %%
library(repr)
options(repr.plot.width=15, repr.plot.height=15)

# %%
library(corrplot)
col <- colorRampPalette(c("#BB4444", "#EE9988", "#FFFFFF", "#77AADD", "#4477AA"))
png(file="CORR_MAT_WA.png",
width=1200, height=1200)
corrplot(M.WA, method="color", col=col(200),  
         type="upper", order="hclust", 
         addCoef.col = "black", # Add coefficient of correlation
         tl.col="black", tl.srt=45, #Text label color and rotation
         # Combine with significance
         p.mat = p.mat.WA, sig.level = 0.01, insig = "blank", 
         # hide correlation coefficient on the principal diagonal
         diag=FALSE 
         )
dev.off()
# Out:
# png
#   2

# %%
# Show full descriptions of selected series
meta.WA[228:247,]
# Out:
#     SeriesID
# 228 A2714990J
# 229 A2714991K
# 230 A2714992L
# 231 A2714993R
# 232 A2714994T
# 233 A2714995V
# 234 A2714996W
# 235 A2714997X
# 236 A2714998A
# 237 A2714999C
# 238 A2715000C
# 239 A2715001F
# 240 A2715002J
# 241 A2715003K
# 242 A2715004L
# 243 A2715005R
# 244 A2715006T
# 245 A2715007V
# 246 A2529254T
# 247 A2478030W
#     Description
# 228 Mining (B) ;  Industry gross value added: Chain volume measures - Percentage changes ;
# 229 Manufacturing (C) ;  Industry gross value added: Chain volume measures - Percentage changes ;
# 230 Electricity, gas, water and waste services (D) ;  Industry gross value added: Chain volume measures - Percentage changes ;
# 231 Construction (E) ;  Industry gross value added: Chain volume measures - Percentage changes ;
# 232 Wholesale trade (F) ;  Industry gross value added: Chain volume measures - Percentage changes ;
# 233 Retail trade (G) ;  Industry gross value added: Chain volume measures - Percentage changes ;
# ...

# %% [markdown]
# ## Explore New South Wales

# %%
head(data.NSW)
# Out:
#   Date       A2336275R A2336276T A2336277V A2336278W A2336279X A2336280J
# 1 1990-06-01 14431     34869     48389     17170     14018     4726
# 2 1991-06-01 15454     35952     50649     17401     14086     4638
# 3 1992-06-01 16097     35624     51208     17541     12800     4863
# 4 1993-06-01 16587     36954     52980     17970     12192     4544
# 5 1994-06-01 16739     37886     53974     18024     12461     4472
# 6 1995-06-01 17778     39096     56357     18774     12358     4521
#   A2336281K A2336282L A2336283R ... A2714118T A2714119V A2714120C A2714121F
# 1 36590     5324      6046      ... NA        NA        NA        NA
# 2 37814     5430      5828      ...  0         0         0         0
# 3 38974     5382      6064      ...  0         0         0         0
# 4 40060     5686      5994      ...  0         0         0         0
# 5 41388     5699      6117      ...  0         0         0         0
# 6 42840     5896      6514      ...  0         0         0         0
# ...

# %%
# Show full descriptions of selected series
meta.NSW[227:247,]
# Out:
#     SeriesID
# 227 A2714913C
# 228 A2714914F
# 229 A2714915J
# 230 A2714916K
# 231 A2714917L
# 232 A2714918R
# 233 A2714919T
# 234 A2714920A
# 235 A2714921C
# 236 A2714922F
# 237 A2714923J
# 238 A2714924K
# 239 A2714925L
# 240 A2714926R
# 241 A2714927T
# 242 A2714928V
# 243 A2714929W
# 244 A2714930F
# 245 A2714931J
# 246 A2529304C
# 247 A2478230R
#     Description
# 227 Agriculture, forestry and fishing (A) ;  Industry gross value added: Chain volume measures - Percentage changes ;
# 228 Mining (B) ;  Industry gross value added: Chain volume measures - Percentage changes ;
# 229 Manufacturing (C) ;  Industry gross value added: Chain volume measures - Percentage changes ;
# 230 Electricity, gas, water and waste services (D) ;  Industry gross value added: Chain volume measures - Percentage changes ;
# 231 Construction (E) ;  Industry gross value added: Chain volume measures - Percentage changes ;
# ...

# %%
head(data.NSW[2:nrow(data.NSW), 228:247])
# Out:
#   A2714913C A2714914F A2714915J A2714916K A2714917L A2714918R A2714919T
# 2  11.9     4.8       -0.6      2.1        1.2      -8.4       0.3
# 3 -10.8     3.0       -2.9      0.9       -9.5      -0.5       4.1
# 4   6.1     3.7       -0.2      2.2        1.5      -2.2      -0.5
# 5   3.7     0.0        4.8      1.7        1.3       6.5       2.4
# 6 -24.5     6.3        1.3      2.5       10.4      11.5       6.0
# 7  34.9     9.1        0.4      1.4        3.4       8.5       5.4
#   A2714920A A2714921C A2714922F A2714923J A2714924K A2714925L A2714926R
# 2 -3.9       1.4       5.3       0.8      -0.5       0.4       1.6
# 3 -0.5       2.2       6.8       6.8      -3.7       4.2       4.6
# 4 -3.6      -0.5      10.9       3.9       8.6      -3.1       3.9
# 5  4.9       3.6       9.0       9.3       3.4       4.6       4.7
# 6  9.1       5.2      13.4      -3.3       7.9      15.1      14.7
# 7  4.1      10.6       2.6       3.0       3.0       0.5      -2.9
# ...

# %%
M.NSW<-cor(data.NSW[2:nrow(data.NSW), 228:247])
M.NSW
# Out:
#           A2714913C   A2714914F    A2714915J   A2714916K    A2714917L
# A2714913C  1.00000000  0.102046704 -0.24217621  0.203343036 -0.15477388
# A2714914F  0.10204670  1.000000000  0.01666986  0.204692533 -0.38538992
# A2714915J -0.24217621  0.016669862  1.00000000  0.207730207  0.10897756
# A2714916K  0.20334304  0.204692533  0.20773021  1.000000000 -0.25921232
# A2714917L -0.15477388 -0.385389924  0.10897756 -0.259212324  1.00000000
# A2714918R -0.10522539  0.051504332  0.24425862  0.008079069  0.18720662
# A2714919T -0.21928893  0.254536641  0.30964367 -0.127919521  0.06224155
# A2714920A  0.07880409  0.210207159  0.19740379 -0.098747038 -0.09335940
# A2714921C  0.02106333  0.453992092  0.42470490  0.096376283 -0.06557738
# A2714922F -0.31723421 -0.062642166  0.42468390 -0.109194323  0.11208830
# A2714923J  0.04793484 -0.121279119  0.12013000 -0.116922695  0.12708758
# A2714924K  0.04559812 -0.117223806 -0.04478895 -0.014182126  0.35334647
# ...

# %%
# matrix of the p-value of the correlation
p.mat.NSW <- cor.mtest(data.NSW[2:nrow(data.NSW), 228:247])
p.mat.NSW
# Out:
#           A2714913C  A2714914F  A2714915J   A2714916K A2714917L  A2714918R
# A2714913C 0.00000000 0.59837131 0.205608022 0.2900685 0.42274484 0.586962919
# A2714914F 0.59837131 0.00000000 0.931603957 0.2868103 0.03895905 0.790751399
# A2714915J 0.20560802 0.93160396 0.000000000 0.2795618 0.57362007 0.201616425
# A2714916K 0.29006848 0.28681029 0.279561815 0.0000000 0.17451409 0.966822409
# A2714917L 0.42274484 0.03895905 0.573620073 0.1745141 0.00000000 0.330838415
# A2714918R 0.58696292 0.79075140 0.201616425 0.9668224 0.33083842 0.000000000
# A2714919T 0.25306304 0.18269646 0.102134415 0.5084255 0.74840101 0.035799782
# A2714920A 0.68449358 0.27373906 0.304686111 0.6103132 0.63002244 0.002134578
# A2714921C 0.91363728 0.01336805 0.021650804 0.6189542 0.73538187 0.019119699
# A2714922F 0.09357328 0.74683383 0.021657986 0.5728534 0.56266216 0.262779634
# A2714923J 0.80496704 0.53085610 0.534785189 0.5458243 0.51120975 0.514700927
# ...

# %%
library(corrplot)
library(repr)

options(repr.plot.width=15, repr.plot.height=15)
col <- colorRampPalette(c("#BB4444", "#EE9988", "#FFFFFF", "#77AADD", "#4477AA"))

png(file="CORR_MAT_NSW.png",
width=1200, height=1200)
corrplot(M.NSW, method="color", col=col(200),  
         type="upper", order="hclust", 
         addCoef.col = "black", # Add coefficient of correlation
         tl.col="black", tl.srt=45, #Text label color and rotation
         # Combine with significance
         p.mat = p.mat.NSW, sig.level = 0.01, insig = "blank", 
         # hide correlation coefficient on the principal diagonal
         diag=FALSE 
         )
dev.off()
# Out:
# png
#   2
